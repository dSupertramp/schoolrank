# %% [markdown]
# <h1>Estrazione delle scuole </h1>
#
# Lo scopo principale del programma è quello di estrarre dall'indirizzo di ogni singola scuola, latitudine e longitudine utilizzando Nominatim.

# %% [markdown]
# Queste sono le librerie utilizzate; di fondamentale importanza è Nominatim.

# %%
import csv
import pandas as pd
import re
from geopy.geocoders import Nominatim
import numpy as np
import urllib
from contextlib import closing
import requests 
import time
from timeit import default_timer as timer
import sys
import codecs

# %% [markdown]
# La funzione <b>cleaner</b> ripulisce l'indirizzo.
# Abbiamo constatato che in OSM (OpenStreetMap), non tutti i numeri civici sono presenti, pertanto, non sapendo quale numero civico è presente in OSM o meno, abbiamo deciso di eliminarli tutti.
# Per ripulire l'indirizzo, abbiamo utilizzato una serie di replace e di regex (in ordine):
#
# <b>Regex: </b>
# - N. seguito da 2 numeri ed uno slash;
# - N. seguito da uno o due numeri;
# - N. seguito da uno spazio e da uno o due numeri;
# - N seguito da uno spazio e da uno o due numeri;
# - Numero civico con slash;
# - Separare via da numero civico
#
# <b>Replace: </b>
# - Sostituzione delle incoerenze, come p.zza al posto di piazza, L.go al posto di largo ecc;
# - Eliminazione del 'senza numero civico' in tutte le sue forme;
# - Vari replace banali

# %%
def cleaner(text):
    regex_dict={
                r"N\.[0-9]{2}\/":r'', 
                r'N\.[0-9]{1,2}':r'', 
                r'N\.\s[0-9]{1,2}':r'',
                r'N\s[0-9]{1,2}':r'', 
                r'[0-9]\/[A-Z]{1}':r'',
                r'([A-Z])(\d{1})': r'\1 \2',
                }

    replace_dict = {
                    'P.ZZA':'PIAZZA',
                    'C.SO':'CORSO',
                    'snc':'',
                    's.n.c':'',
                    's.n.':'',
                    'L.GO':'LARGO',
                    'PROLUNG.':'PROLUNGAMENTO ',
                    '"':'',
                    'P.AZA':'PIAZZA',
                    '-':''
                    }
    #keywords
    for key, values in replace_dict.items():
        text = text.replace(key, values)
    #regex
    for key in regex_dict:
        rx = re.compile(key)
        text = rx.sub(regex_dict[key], text)
    return text

# %% [markdown]
# Qui avviene l'estrazione vera e propria:
# Dall' URL, utilizzando urllib andiamo ad estrarre direttamente il file relativo alle scuole, che viene letto utilizzando il DictReader.
# A fine file, troverà il perchè abbiamo utilizzato DictReader e altri accorgimenti.
# Dal csv, andiamo ad estrarre i campi interessati, come l'indirizzo della scuola, il codice, il tipo di scuola ecc.
#
# OSM blocca l'accesso dopo un elevato numero di richieste, pertanto abbiamo deciso di scomporre il tutto per città (in questo caso Palermo).
#
# Nominatim tenterà di effettuare il geocoding dell'indirizzo, inserendo <b>None</b> se non troverà nulla.
#
# Il <b>timer</b> è stato inserito per effettuare un piccolo controllo sulla velocità di geocode di ogni singolo indirizzo.
#
# Successivamente verranno scritti sull'output i diversi campi.
#
# Se una scuola non possiede un sito web, sarà presente la stringa 'Non disponibile', che verrà rimossa; inoltre, al sitoweb, viene aggiunto il protocollo http, che non è presente.
#
# Il file verrà riaperto utilizzando <b>pandas</b>, quindi come <b>DataFrame</b>, e da qui, andremo ad eliminare tutte le righe in cui non è presente la latitudine (o longitudine, è indifferente).
#
# Il DataFrame è una struttura dati molto veloce e prestante, infatti abbiamo deciso di utilizzarla sia per la facilità con il quale vengono eliminate molte righe, sia per una questione di tempi computazionali.
#
#
# L'indirizzo è stato trattato nel seguente modo:
# - Prendiamo l'indirizzo non pulito dal dataset,
# - Applichiamo la funzione cleaner su di esso,
# - Aggiungiamo il cap (migliora notevolmente la precisione)
#
# Nel file di output, aggiungeremo l'indirizzo privo di cap:

# %%
# coding: utf-8
import csv
import pandas as pd
import re
from geopy.geocoders import Nominatim
import numpy as np
import urllib
from contextlib import closing
import requests
import time
from timeit import default_timer as timer
import sys
import codecs


def cleaner(text):
    regex_dict = {
        r"N\.[0-9]{2}\/": r'',
        r'N\.[0-9]{1,2}': r'',
        r'N\.\s[0-9]{1,2}': r'',
        r'N\s[0-9]{1,2}': r'',
        r'[0-9]\/[A-Z]{1}': r'',
        r'([A-Z])(\d{1})': r'\1 \2',
    }

    replace_dict = {
        'P.ZZA': 'PIAZZA',
        'C.SO': 'CORSO',
        'snc': '',
        's.n.c': '',
        's.n.': '',
        'L.GO': 'LARGO',
        'PROLUNG.': 'PROLUNGAMENTO ',
                    '"': '',
                    'P.AZA': 'PIAZZA',
                    '-': ''
    }
    # keywords
    for key, values in replace_dict.items():
        text = text.replace(key, values)
    # regex
    for key in regex_dict:
        rx = re.compile(key)
        text = rx.sub(regex_dict[key], text)
    return text


# Estrazione
with open('Output_estrazione.csv', 'w', newline='') as csvoutput:
    output_fieldnames = ['NOMESCUOLA', 'DESCRIZIONECOMUNE', 'CODICESCUOLA', 'INDIRIZZO', 'LATITUDINE', 'LONGITUDINE',
                         'SITOWEB', 'DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA', 'CODICEISTITUTORIFERIMENTO', 'CAPSCUOLA']
    writer = csv.DictWriter(csvoutput, delimiter=',',
                            fieldnames=output_fieldnames)
    writer.writeheader()
    url = 'http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/SCUANAGRAFESTAT20181920180901.csv'
    response = urllib.request.urlopen(url)
    reader = csv.DictReader(codecs.iterdecode(response, 'utf-8'))
    geolocator = Nominatim(user_agent="my-application")
    comune = 'PALERMO'
    for row in reader:
        indirizzo = row['INDIRIZZOSCUOLA']
        indirizzo_pulito = cleaner(indirizzo)
        codice_istituto = row['CODICESCUOLA']
        descrizione_comune = row['DESCRIZIONECOMUNE']
        nome_scuola = row['DENOMINAZIONEISTITUTORIFERIMENTO']
        sito_web = row['SITOWEBSCUOLA']
        tipologia_scuola = row['DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA']
        codice_istituto_riferimento = row['CODICEISTITUTORIFERIMENTO']
        cap_scuola = row['CAPSCUOLA']
        indirizzo_pulito_cap = indirizzo_pulito+' '+row['CAPSCUOLA']
        if str(comune) == str(descrizione_comune).upper():
            try:
                start = timer()
                location = geolocator.geocode(indirizzo_pulito_cap)
                latitude = location.latitude
                longitude = location.longitude
                end = timer()
                print(end-start)
            except:
                latitude = None
                longitude = None
            # Scrittura
            output_row = {}
            output_row['NOMESCUOLA'] = nome_scuola
            output_row['DESCRIZIONECOMUNE'] = descrizione_comune.upper()
            output_row['CODICESCUOLA'] = codice_istituto
            output_row['INDIRIZZO'] = indirizzo_pulito.upper()
            output_row['DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA'] = tipologia_scuola
            output_row['LATITUDINE'] = latitude
            output_row['LONGITUDINE'] = longitude
            if 'non' in sito_web.lower():
                output_row['SITOWEB'] = None
            else:
                output_row['SITOWEB'] = 'http://'+sito_web.lower()
            output_row['CODICEISTITUTORIFERIMENTO'] = codice_istituto_riferimento
            output_row['CAPSCUOLA'] = cap_scuola
            writer.writerow(output_row)


df = pd.read_csv('Output_estrazione.csv')
df.dropna(subset=['LATITUDINE'], how='all', inplace=True)
df.to_csv('Output_estrazione.csv', index=False)
# Out:
# 0.5750460000001567
# 0.546332300000131
# 0.6240651999999045
# 0.475332200000139
# 0.5010131999999885
# 0.8034494000000905
# 0.8227155000001858
# 0.521442099999831
# 0.49232089999986783
# 0.53922979999993
# 0.831624500000089
# 1.0756039000000328
# 0.4863460000001396
# 0.789245499999879
# 1.2351542000001245
# 0.5083442000000105
# 0.7514933999998448
# 0.4878105999998752
# 0.46403399999985595
# 0.6560617000000093
# 0.5104992000001403
# 0.509552499999927
# 0.7980916999999863
# 0.7768325000001823
# 0.643824099999847
# 0.7414039999998749
# 0.5268926999999621
# 0.537776200000053
# 0.5122954000000846
# 0.5988697000000229
# 0.5724165999999968
# 0.544834499999979
# 0.5384438999999475
# 0.5756070999998428
# 0.5065114000001358
# 0.535566400000107
# 0.5341060000000653
# 0.8087222000001475
# 0.6649686999999176
# 0.49860260000014023
# 0.52843299999995
# 0.5289296999999351
# 1.142404899999974
# 1.1305442000000312
# 0.6241683999999168
# 0.6632588999998461
# 0.6268572000001313
# 0.5232336999999916
# 0.5526484000001801
# 0.5715692999999646
# 0.5090950999999677
# 0.6060099999999693
# 1.4461751999999706
# 0.8219724000000497
# 0.5373222999999143
# 0.5076461000001018
# 1.2387145999998666
# 0.5203403000000435
# 0.6217109000001528
# 0.7985305999998218
# 0.5047202000000652
# 0.5403851000000941
# 0.5533303999998225
# 0.6655955999999605
# 0.8076456999999664
# 0.5138644999999542
# 0.8571154999999635
# 0.46175089999997
# 0.5760775000001104
# 0.6790426999998544
# 0.6207362000000103
# 0.8872424999999566
# 0.5256408000000192
# 0.5283288999999058
# 0.5290969000000132
# 0.5327187999998841
# 0.6069511000000603
# 0.5508084000000508
# 0.4673903000000337
# 0.839765300000181
# 0.5594234999998662
# 0.49474110000005567
# 0.4782141999999112
# 1.1125782999997682
# 0.561225899999954
# 0.5002529999997023
# 0.553443100000095
# 0.8302407999999559
# 0.5880762000001596
# 0.5516511999999238
# 0.5200506000001042
# 0.5220377000000553
# 0.5269555999998374
# 0.583100899999863
# 0.5131967000002078
# 0.6268506999999772
# 0.4755292000004374
# 0.5334333999999217
# 0.7824639999998908
# 0.7695478999999068
# 0.6408667999999125
# 0.5156815000000279
# 0.4875566999999137
# 0.5061063999996804
# 0.5999510999999984
# 0.46938300000010713
# 0.8693487999998979
# 0.5681008000001384
# 0.48890430000028573
# 0.5300551000000269
# 0.5586140999998861
# 0.5203065999999126
# 0.46228419999988546
# 0.4901362999999037
# 0.49223540000002686
# 0.9863755999999739
# 0.4955974999998034
# 0.5504258000000846
# 0.5225666000001183
# 0.5156749000002492
# 0.8682507999997142
# 0.5197659000000385
# 0.541781699999774
# 0.6095585999996729
# 0.5289709000003313
# 0.803633400000308
# 0.48821029999999155
# 0.5362147999999252
# 0.5104606999998396
# 0.8075150000004214
# 0.5426051999997981
# 0.5009629000001041
# 0.4612891000001582
# 0.8124590000002172
# 0.5295120999999199
# 0.5570572999999968
# 0.4888433000000987
# 0.8274666000002071
# 0.4922622999997657
# 0.4606097000000773
# 0.5558949999999641
# 0.8048757000001387
# 0.5527258000001893
# 0.5807196000000658
# 0.5169227000001229
# 1.0994412000000011
# 0.8330678000002081
# 0.534298100000342
# 0.8837930999998207
# 0.5366447000001244
# 0.5152791000000434
# 1.1103935999999521
# 0.8823030999997172
# 0.5399714000000131
# 0.4888530000002902
# 0.8246212999997624
# 0.5340338000000884
# 0.4708680000003369
# 0.6023528000000624
# 1.059557699999914
# 0.4911928000001353
# 0.4865852000002633
# 0.6219430999999531
# 0.514270900000156
# 0.5232927999995809
# 0.8553769000000102
# 0.5280946000002587
# 0.5627215999998043
# 1.136661600000025
# 0.4961719000002631
# 0.5177251000000069
# 0.7906867000001512
# 0.5291602000002058
# 0.8918687999998838
# 0.49977389999958177
# 0.9190822999999
# 0.5436520000002929
# 0.614965399999619
# 0.5402708999999959

# %% [markdown]
# Ecco il file:

# %%
df
# Out:
#                           NOMESCUOLA DESCRIZIONECOMUNE CODICESCUOLA  \
# 1                           A. VOLTA           PALERMO   PAIS027002
# 2          I.C. LEONARDO SCIASCIA-PA           PALERMO   PAAA870011
# 6          I.C. LEONARDO SCIASCIA-PA           PALERMO   PAEE870016
# 10   I.C. M.RAPISARDI /GARIBALDI -PA           PALERMO   PAEE8AP019
# 12         I.C. LEONARDO SCIASCIA-PA           PALERMO   PAIC870004
# 17                I.C. POLITEAMA -PA           PALERMO   PAIC890009
# 18         EDUCANDATO MARIA ADELAIDE           PALERMO   PAEE89401P
# 19    I.P.S.S.E.O.A. "PIETRO PIAZZA"           PALERMO   PARH02050Q
# 24           D.D. A. DE GASPERI - PA           PALERMO   PAEE013002
# 27     I.C. RITA LEVI MONTALCINI -PA           PALERMO   PAAA8A0019
# 29            D.D. E. DE AMICIS - PA           PALERMO   PAEE01703C
# 34     I.C. RITA LEVI MONTALCINI -PA           PALERMO   PAIC8A000C
# 37            D.D. E. DE AMICIS - PA           PALERMO   PAAA017048
# 38      I.C. MANZONI /IMPASTATO - PA           PALERMO   PAAA87901B
# 39           D.D. A. DE GASPERI - PA           PALERMO   PAAA013052
# 42      I.C. MANZONI /IMPASTATO - PA           PALERMO   PAIC87900E
# 44           D.D. A. DE GASPERI - PA           PALERMO   PAAA01303X
# 45     I.C. RITA LEVI MONTALCINI -PA           PALERMO   PAMM8A001D
# 46      I.C. MANZONI /IMPASTATO - PA           PALERMO   PAAA87902C
# 47    I.C.PEREZ-M.TERESA DI CALCUTTA           PALERMO   PAMM813011
# 48           D.D. A. DE GASPERI - PA           PALERMO   PAAA013041
# 49     I.C. RITA LEVI MONTALCINI -PA           PALERMO   PAEE8A002G
# 50          I.C. RUSSO / RACITI - PA           PALERMO   PAEE8AZ011
# 55          I.C. RUSSO / RACITI - PA           PALERMO   PAAA8AZ02R
# 56    I.C.PEREZ-M.TERESA DI CALCUTTA           PALERMO   PAEE813012
# 57      I.C. MANZONI /IMPASTATO - PA           PALERMO   PAEE87903P
# 68              D.D. A. GABELLI - PA           PALERMO   PAAA01903V
# 71          I.C. RUSSO / RACITI - PA           PALERMO   PAEE8AZ022
# 74              D.D. A. GABELLI - PA           PALERMO   PAEE019001
# 77                    CPIA PALERMO 1           PALERMO   PACT72000X
# ..                               ...               ...          ...
# 434          D.D. ROSOLINO PILO - PA           PALERMO   PAAA039067
# 436                 L.EINAUDI-PARETO           PALERMO   PAIS03700L
# 437      I.C. GIULIANA SALADINO - PA           PALERMO   PAAA897033
# 438  I.C. I. FLORIO - S. LORENZO -PA           PALERMO   PAEE8AX019
# 440          D.D. RAGUSA MOLETI - PA           PALERMO   PAAA03710R
# 441       I.C. MANTEGNA /BONANNO -PA           PALERMO   PAIC85300A
# 446          D.D. RAGUSA MOLETI - PA           PALERMO   PAAA03708N
# 447  I.C. GIOVANNI XXIII /PIAZZI -PA           PALERMO   PAAA8AL01R
# 450   CONVITTO NAZIONALE- G. FALCONE           PALERMO   PAIC89500C
# 451            D.D. F. ORESTANO - PA           PALERMO   PAEE03207P
# 452   D.D. F. SAVERIO CAVALLARI - PA           PALERMO   PAEE012006
# 454  I.C. GIOVANNI XXIII /PIAZZI -PA           PALERMO   PAIC8AL00X
# 455    D.D. ALESSANDRA SIRAGUSA - PA           PALERMO   PAEE033029
# 456            D.D. F. ORESTANO - PA           PALERMO   PAEE03200B
# 458              I.C. MAREDOLCE - PA           PALERMO   PAEE8AV03Q
# 459          I.C. SILVIO BOCCONE -PA           PALERMO   PAAA8A2011
# 462              I.C. MAREDOLCE - PA           PALERMO   PAMM8AV01L
# 463            D.D. F. ORESTANO - PA           PALERMO   PAAA03207D
# 465          I.C. SILVIO BOCCONE -PA           PALERMO   PAIC8A2004
# 466              I.C. MAREDOLCE - PA           PALERMO   PAIC8AV00G
# 468      D.D. PARTANNA MONDELLO - PA           PALERMO   PAAA03402X
# 469                   ERNESTO BASILE           PALERMO   PAPS060003
# 479            S.D'ACQUISTO BAGHERIA           PALERMO   PARI010029
# 480  I.C. UDITORE /SETTI CARRARO -PA           PALERMO   PAEE8AQ026
# 481         I.C. LOMBARDO RADICE -PA           PALERMO   PAIC8AD00Q
# 487         I.C. LOMBARDO RADICE -PA           PALERMO   PAEE8AD01T
# 489                         A. VOLTA           PALERMO   PATF02750V
# 490      D.D. PARTANNA MONDELLO - PA           PALERMO   PAEE034069
# 491            I.C. SCINA'/COSTA -PA           PALERMO   PAMM8AC011
# 492               I.C. POLITEAMA -PA           PALERMO   PAMM89001A
#
#                          INDIRIZZO  LATITUDINE  LONGITUDINE  \
# 1        PASSAGGIO DEI PICCIOTTI 1   38.104349    13.384438
# 2                        VIA SMITH   49.809512   -97.139668
# 6                  VIA ADAMO SMITH   38.177230    13.311783
# 10            VIA CALTANISSETTA 27   38.128882    13.350617
# 12      VIA FRANCESCO DE GOBBIS 13   38.178900    13.310333
# 17           PIAZZA CASTELNUOVO 40   38.124514    13.355120
# 18             CORSO CALATAFIMI 86   38.103186    13.330621
# 19             CORSO DEI MILLE 181   38.100146    13.384509
# 24   PIAZZA PAPA GIOVANNI PAOLO II   38.152381    13.337908
# 27                LARGO CAMASTRA 5   38.127671    13.297750
# 29        VIA ROSSO DI S.SECONDO 1   38.120384    13.329170
# 34                 PIAZZA S.PAOLO    38.129380    13.292036
# 37         VIA ROSSO DI S. SECONDO   38.120384    13.329170
# 38              VIA SERRADIFALCO 3   38.120368    13.341268
# 39             PIAZZETTA SALERNO 1   40.717274    14.906834
# 42        VIA FILIPPO PARLATORE 56   38.126237    13.343142
# 44   PIAZZA PAPA GIOVANNI PAOLO II   38.152381    13.337908
# 45           PIAZZA SANTA CRISTINA   38.129887    13.299011
# 46              VIA PIETRO MERENDA   38.126428    13.340219
# 47                    VIA FIUME 14   38.112095    13.364523
# 48                   VIA BRIUCCIA    38.152324    13.333585
# 49                 LARGO CAMASTRA    38.127671    13.297750
# 50              LARGO GIBILMANNA 8   38.130978    13.295750
# 55                LARGO GIBILMANNA   38.130978    13.295750
# 56                    VIA FIUME 14   38.112095    13.364523
# 57              VIA PIETRO MERENDA   38.126428    13.340219
# 68                  PIAZZA ZISA 21   38.115782    13.341109
# 71                        VIA ALIA   38.132554    13.295770
# 74          VIA EUGENIO L'EMIRO 30   38.114492    13.338779
# 77         VIA PIER DELLE VIGNE 13   38.130281    13.358647
# ..                             ...         ...          ...
# 434    VIA SEBASTIANO LA FRANCA 70   38.103329    13.364122
# 436              VIA MONGERBINO 51   38.139214    13.332822
# 437     PIAZZA BENVENUTO CELLINI 4   38.137733    13.309077
# 438             VIA SAN LORENZO 89   38.161259    13.325415
# 440                    VIA TITONE    38.107142    13.337758
# 441                  VIA BOLOGNI 4   38.111576    13.308409
# 446            VIA RAGUSA MOLETI 8   38.106669    13.339396
# 447                 VIA SAMPOLO 63   38.139696    13.351926
# 450           PIAZZA SETT'ANGELI 3   38.114475    13.356703
# 451                 VIA SAN CIRO 4   38.091435    13.384228
# 452            CORSO DEI MILLE 793   38.100146    13.384509
# 454           VIA MARIO RUTELLI 50   38.139315    13.347870
# 455            VIA SAN LORENZO 295   38.161259    13.325415
# 456           VIA CONTE FEDERICO 1   38.086359    13.398310
# 458             VIA VILLAGRAZIA 40   38.097745    13.368118
# 459                  VIA ORETO 106   38.106204    13.367606
# 462              VIA FICHIDINDIA 6   38.096250    13.374936
# 463           VIA CONTE FEDERICO 3   38.093097    13.386767
# 465              VIA DEL VESPRO 72   38.103791    13.362680
# 466              VIA FICHIDINDIA 6   38.096250    13.374936
# 468                  VIA NETTUNO 6   38.196245    13.316676
# 469                VIA SAN CIRO 23   38.091435    13.384228
# 479    VIA PRINCIPE DI PALAGONIA 5   38.132256    13.337404
# 480                 VIA UDITORE 21   38.133015    13.322953
# 481            CORSO CALATAFIMI 24   38.103186    13.330621
# 487           CORSO CALATAFIMI 241   38.103186    13.330621
# 489   VIA PASSAGGIO DEI PICCIOTTI    38.104349    13.384438
# 490                 VIA MONDELLO 5   38.206238    13.324304
# 491       VIA GIUSEPPE LI BASSI 60   38.100270    13.352931
# 492        VIA PIER DELLE VIGNE 13   38.130281    13.358647
#
#                                              SITOWEB  \
# 1                                                NaN
# 2                 http://www.istitutosciascia.gov.it
# 6                 http://www.istitutosciascia.gov.it
# 10                  http://www.rapisardigaribaldi.it
# 12                                               NaN
# 17                                               NaN
# 18                 http://http//www.mariaadelaide.it
# 19                        http://www.ipssarpiazza.it
# 24                                               NaN
# 27               http://www.icsritalevimontalcini.it
# 29                      http://www.deamicispa.gov.it
# 34                                               NaN
# 37                          http://www.deamicispa.it
# 38                    http://www.manzoniimpastato.it
# 39                 http://www.primariadegasperipa.it
# 42                                               NaN
# 44               http://www.ddalcidedegasperi.gov.it
# 45              http://www.icsritalevimontalcini.it/
# 46                    http://www.manzoniimpastato.it
# 47             http://www.icmadreteresadicalcutta.it
# 48              http://www.ddalcidedegasperi. gov.it
# 49              http://www.icsritalevimontalcini.it/
# 50                       http://www.icrussoraciti.it
# 55                       http://www.icrussoraciti.it
# 56   http://www.icsperezmadreteresadicalcutta.gov.it
# 57                    http://www.peppinoimpastato.it
# 68                       http://www.ddgabelli.gov.it
# 71                       http://www.icrussoraciti.it
# 74                                               NaN
# 77                                               NaN
# ..                                               ...
# 434              http://www.scuolapilopalermo.gov.it
# 436                                              NaN
# 437                 http://www.icgiulianasaladino.it
# 438             http://www.icfloriosanlorenzo.gov.it
# 440                 http://www.ddragusamoleti.gov.it
# 441                                              NaN
# 446                 http://www.ddragusamoleti.gov.it
# 447                     http://icgiovanni23piazzi.it
# 450                                              NaN
# 451                     http://www.scuolaorestano.it
# 452                                              NaN
# 454                                              NaN
# 455                  http://www.ddpallavicino.gov.it
# 456                                              NaN
# 458                       http://www.icsmaredolce.it
# 459                         http://www.icsboccone.it
# 462                       http://www.icsmaredolce.it
# 463     http://www.direzionedidatticaorestano.gov.it
# 465                                              NaN
# 466                                              NaN
# 468                http://www.ddspartannamondello.it
# 469                        http://www.liceobasile.it
# 479                      http://www.ipsiabagheria.eu
# 480             http://icuditore-setticarraro.gov.it
# 481                                              NaN
# 487          http://www.comprensivolombardoradice.it
# 489                        http://www.itivolta.pa.it
# 490                 http://www.ddpartannamondello.it
# 491      http://http//icscinacosta.xoom.it/scina.htm
# 492                       http://www.icspoliteama.it
#
#              DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA  \
# 1                                   ISTITUTO SUPERIORE
# 2                                      SCUOLA INFANZIA
# 6                                      SCUOLA PRIMARIA
# 10                                     SCUOLA PRIMARIA
# 12                                ISTITUTO COMPRENSIVO
# 17                                ISTITUTO COMPRENSIVO
# 18                                     SCUOLA PRIMARIA
# 19   IST PROF PER I SERVIZI ALBERGHIERI E RISTORAZIONE
# 24                                     SCUOLA PRIMARIA
# 27                                     SCUOLA INFANZIA
# 29                                     SCUOLA PRIMARIA
# 34                                ISTITUTO COMPRENSIVO
# 37                                     SCUOLA INFANZIA
# 38                                     SCUOLA INFANZIA
# 39                                     SCUOLA INFANZIA
# 42                                ISTITUTO COMPRENSIVO
# 44                                     SCUOLA INFANZIA
# 45                                  SCUOLA PRIMO GRADO
# 46                                     SCUOLA INFANZIA
# 47                                  SCUOLA PRIMO GRADO
# 48                                     SCUOLA INFANZIA
# 49                                     SCUOLA PRIMARIA
# 50                                     SCUOLA PRIMARIA
# 55                                     SCUOLA INFANZIA
# 56                                     SCUOLA PRIMARIA
# 57                                     SCUOLA PRIMARIA
# 68                                     SCUOLA INFANZIA
# 71                                     SCUOLA PRIMARIA
# 74                                     SCUOLA PRIMARIA
# 77                                 CENTRO TERRITORIALE
# ..                                                 ...
# 434                                    SCUOLA INFANZIA
# 436                                 ISTITUTO SUPERIORE
# 437                                    SCUOLA INFANZIA
# 438                                    SCUOLA PRIMARIA
# 440                                    SCUOLA INFANZIA
# 441                               ISTITUTO COMPRENSIVO
# 446                                    SCUOLA INFANZIA
# 447                                    SCUOLA INFANZIA
# 450                               ISTITUTO COMPRENSIVO
# 451                                    SCUOLA PRIMARIA
# 452                                    SCUOLA PRIMARIA
# 454                               ISTITUTO COMPRENSIVO
# 455                                    SCUOLA PRIMARIA
# 456                                    SCUOLA PRIMARIA
# 458                                    SCUOLA PRIMARIA
# 459                                    SCUOLA INFANZIA
# 462                                 SCUOLA PRIMO GRADO
# 463                                    SCUOLA INFANZIA
# 465                               ISTITUTO COMPRENSIVO
# 466                               ISTITUTO COMPRENSIVO
# 468                                    SCUOLA INFANZIA
# 469                                  LICEO SCIENTIFICO
# 479                   IST PROF INDUSTRIA E ARTIGIANATO
# 480                                    SCUOLA PRIMARIA
# 481                               ISTITUTO COMPRENSIVO
# 487                                    SCUOLA PRIMARIA
# 489                       ISTITUTO TECNICO INDUSTRIALE
# 490                                    SCUOLA PRIMARIA
# 491                                 SCUOLA PRIMO GRADO
# 492                                 SCUOLA PRIMO GRADO
#
#     CODICEISTITUTORIFERIMENTO CAPSCUOLA
# 1                  PAIS027002     90123
# 2                  PAIC870004     90100
# 6                  PAIC870004     90146
# 10                 PAIC8AP007     90141
# 12                 PAIC870004     90146
# 17                 PAIC890009     90141
# 18                 PAIC89400L     90129
# 19                 PARH02000A     90123
# 24                 PAEE013002     90146
# 27                 PAIC8A000C     90135
# 29                 PAEE017009     90135
# 34                 PAIC8A000C     90135
# 37                 PAEE017009     90135
# 38                 PAIC87900E     90145
# 39                 PAEE013002     90146
# 42                 PAIC87900E     90145
# 44                 PAEE013002     90146
# 45                 PAIC8A000C     90135
# 46                 PAIC87900E     90145
# 47                 PAIC81300X     90133
# 48                 PAEE013002     90146
# 49                 PAIC8A000C     90135
# 50                 PAIC8AZ00V     90135
# 55                 PAIC8AZ00V     90100
# 56                 PAIC81300X     90133
# 57                 PAIC87900E     90145
# 68                 PAEE019001     90135
# 71                 PAIC8AZ00V     90100
# 74                 PAEE019001     90135
# 77                 PAMM15700G     90139
# ..                        ...       ...
# 434                PAEE039006     90127
# 436                PAIS03700L     90144
# 437                PAIC897004     90145
# 438                PAIC8AX007     90146
# 440                PAEE03700E     90129
# 441                PAIC85300A     90136
# 446                PAEE03700E     90129
# 447                PAIC8AL00X     90143
# 450                PAIC89500C     90134
# 451                PAEE03200B     90124
# 452                PAEE012006     90123
# 454                PAIC8AL00X     90143
# 455                PAEE033007     90146
# 456                PAEE03200B     90124
# 458                PAIC8AV00G     90124
# 459                PAIC8A2004     90127
# 462                PAIC8AV00G     90124
# 463                PAEE03200B     90124
# 465                PAIC8A2004     90127
# 466                PAIC8AV00G     90124
# 468                PAEE034003     90151
# 469                PAPS060003     90124
# 479                PARI010007     90146
# 480                PAIC8AQ003     90145
# 481                PAIC8AD00Q     90129
# 487                PAIC8AD00Q     90129
# 489                PAIS027002     90123
# 490                PAEE034003     90151
# 491                PAIC8AC00X     90128
# 492                PAIC890009     90139
#
# [179 rows x 10 columns]

# %% [markdown]
# Il file <b>Output_estrazione</b> contiene:
# - Nome scuola,
# - Descrizione comune,
# - Codice della scuola,
# - Indirizzo della scuola,
# - Latitudine
# - Longitudine
# - Sitoweb
# - Tipo di scuola
# - Codice istituto di riferimento
# - CAP della scuola
#
# Il codice istituto di riferimento rappresenta il codice univoco per ogni scuola, e serve inoltre per distinguere la scuola principale dal plesso.

# %% [markdown]
# <h3>Perchè abbiamo scelto CSV DictReader? </h3>
#
# Abbiamo provato ad utilizzare direttamente pandas, leggendo il file direttamente come DataFrame:

# %%
df=pd.read_csv('http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/SCUANAGRAFESTAT20181920180901.csv.csv')
comune = 'PALERMO'
df = df.loc[df['DESCRIZIONECOMUNE']==comune]
df['INDIRIZZOSCUOLA'] = df['INDIRIZZOSCUOLA']+' '+df['CAPSCUOLA']
df['INDIRIZZOSCUOLA'] = df['INDIRIZZOSCUOLA'].apply(cleaner)


geolocator = Nominatim(user_agent = "my-application")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
f = pd.DataFrame()
f['INDIRIZZO'] = geolocator.geocode(str(df['INDIRIZZOSCUOLA']))
f['LATITUDINE'] = str(f['INDIRIZZO']).latitude
f['LONGITUDINE'] = str(f['INDIRIZZO']).longitude


f.dropna(subset=['COORDINATE'], how='all', inplace = True)
f.to_csv('Output_estrazione.csv', index=False)

# %% [markdown]
# Secondo la documentazione di <b>GeoPy</b>, per poter usare il geocode con pandas, bisogna impostare un rate_limiter, in modo da limitare le richieste,
# che va a rallentare l'intero processo di estrazione. Per questo motivo, abbiamo deciso di utilizzare il DictReader per l'estrazione dei dati.
#
#
# Qui viene riportata la parte di documentazione che fa riferimento al geocode con pandas:
#
# <i><b>"It's possible to geocode a pandas DataFrame with geopy, however, rate-limiting must be taken into account.
#
# A large number of DataFrame rows might produce a significant amount of geocoding requests to a Geocoding service,
# which might be throttled by the service (e.g. by returning Too Many Requests 429 HTTP error or timing out).
#
# geopy.extra.rate_limiter.RateLimiter class provides a convenient wrapper,
# which can be used to automatically add delays between geocoding calls to reduce the load on the Geocoding service.
# Also it can retry failed requests and swallow errors for individual rows."</b></i>
#
# <i>È sconsigliata l'esecuzione del codice soprastante, in quanto i tempi di attesa potrebbero essere elevati.</i>

# %% [markdown]
# <h1>Bonus: OSM vs Google API</h1>

# %% [markdown]
# Abbiamo deciso di testare le API per il geocode di Google, confrontandone i tempi.
# Ecco alcuni tempi di OSM:
#
# 0.5750460000001567<br>
# 0.546332300000131<br>
# 0.6240651999999045<br>
# 0.475332200000139<br>
# 0.5010131999999885<br>
# 0.8034494000000905<br>
# 0.8227155000001858<br>
# 0.521442099999831<br>
# 0.49232089999986783<br>
# 0.53922979999993<br>
#
#
#
# La media di questi tempi è: 0.59009466000002, quindi circa 1/2 secondo di tempo per indirizzo.
#
# Per quanto riguarda Google API, abbiamo ottenuto un unico risultato, ovvero: 2.303347826.

# %% [markdown]
# <h3>Prova Google:</h3>

# %%
gmaps = googlemaps.Client(key='AIzaSyBhgjHA4LD7KjVqvYOhquOkgEQJ9fNI-Jk')
geocode_result = gmaps.geocode(str(df['INDIRIZZOSCUOLA']))
f = pd.DataFrame()
f['INDIRIZZO'] = df['INDIRIZZOSCUOLA']
f['LATITUDINE'] = geocode_result[0]["geometry"]["location"]["lat"]
f['LONGITUDINE'] = geocode_result[0]["geometry"]["location"]["lng"]
f.dropna(subset=['LATITUDINE'], how='all', inplace = True)
f.to_csv('Output_googleapi.csv', index=False)
