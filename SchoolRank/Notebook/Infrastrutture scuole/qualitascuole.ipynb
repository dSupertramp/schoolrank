# %% [markdown]
# <h1>Qualità delle scuole</h1>
#
# Lo scopo principale del programma è quello di estrarre un 'rank', ovvero una valutazione della scuola, che si basa su riscaldamento, presenza di macro ambienti funzionali e presenza di barriere architettoniche.
#
# I dataset relativi alla qualità delle scuole appartengono all'anno 17/18, pertanto possono esserci delle differenze, che abbiamo corretto negli altri file.

# %% [markdown]
# Librerie utilizzate:

# %%
import csv
import pandas as pd
import re
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import numpy as np
from contextlib import closing
import requests 
import time
import sys

# %% [markdown]
# Successivamente andiamo a prelevare i 3 dataset e inserirli in dei DataFrame, che verranno ordinati per codice scuola.
# Tramite loc, andiamo a prelevare solo le righe il cui codice scuola fa riferimento ad una scuola di Palermo:
#
# <i>Il PA presente nel contains indica Palermo, pertanto si possono utilizzare anche altre sigle, come CT per Catania e così via.</i>

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
# la sigla identifica direttamente il comune, eliminando le provincie
# es: PA indica tutte le scuole appartenenti a Palermo come citta
sigla = 'PA'

ambiente = pd.read_csv(
    'http://dati.istruzione.it/opendata/opendata/catalogo/elements1/leaf/EDIAMBFUNZSTA20171820180925.csv')
barriera = pd.read_csv(
    'http://dati.istruzione.it/opendata/EDISUPBARARCSTA20171820180925.csv')
riscaldamento = pd.read_csv(
    'http://dati.istruzione.it/opendata/EDITIPORISCSTA20171820180925.csv')

ambiente = ambiente.sort_values(by=['CODICESCUOLA'])
riscaldamento = riscaldamento.sort_values(by=['CODICESCUOLA'])
barriera = barriera.sort_values(by=['CODICESCUOLA'])

# %% [markdown]
# Costruiamo i vari DataFrame:

# %%
#Ambienti
df1['CODICESCUOLA'] = ambiente['CODICESCUOLA']
df1['CODICEEDIFICIO'] = ambiente['CODICEEDIFICIO']
df1['SPAZIDIDATTICI']=ambiente['SPAZIDIDATTICI']
df1['AULAMAGNA']=ambiente['AULAMAGNA']
df1['MENSA']=ambiente['MENSA']
df1['PALESTRAPISCINA']=ambiente['PALESTRAPISCINA']
df1['SPAZIAMMINISTRATIVI']=ambiente['SPAZIAMMINISTRATIVI']

#Barriere
df2['CODICESCUOLA'] = barriera['CODICESCUOLA']
df2['CODICEEDIFICIO'] = barriera['CODICEEDIFICIO']
df2['SUPERAMENTOBARRIEREARCH']=barriera['SUPERAMENTOBARRIEREARCH']
df2['ACCESSORAMPE']=barriera['ACCESSORAMPE']
df2['SCALENORMA']=barriera['SCALENORMA']
df2['ASCENSOREDISABILI']=barriera['ASCENSOREDISABILI']
df2['PIATTAFORMAELEVATRICE']=barriera['PIATTAFORMAELEVATRICE']
df2['SERVIZIIGIENICIDISABILI']=barriera['SERVIZIIGIENICIDISABILI']
df2['PORTELARGHEZZADISABILI']=barriera['PORTELARGHEZZADISABILI']
df2['PERCORSIINTERNIDISABILI']=barriera['PERCORSIINTERNIDISABILI']
df2['PERCORSIESTERNIDISABILI']=barriera['PERCORSIESTERNIDISABILI']
df2['ALTRIACCORGIMENTIDISABILI']=barriera['ALTRIACCORGIMENTIDISABILI']

#Riscaldamento
df3['CODICESCUOLA'] = riscaldamento['CODICESCUOLA']
df3['CODICEEDIFICIO'] = riscaldamento['CODICEEDIFICIO']
df3['IMPIANTORISCALDAMENTO']=riscaldamento['IMPIANTORISCALDAMENTO']
df3['CENTRALIZZATOOLIOCOMBUSTIBILI']=riscaldamento['CENTRALIZZATOOLIOCOMBUSTIBILI']
df3['CENTRALIZZATOGASOLIO']=riscaldamento['CENTRALIZZATOGASOLIO']
df3['CENTRALIZZATOMETANO']=riscaldamento['CENTRALIZZATOMETANO']
df3['CENTRALIZZATOGPL']=riscaldamento['CENTRALIZZATOGPL']
df3['CENTRALIZZATOARIA']=riscaldamento['CENTRALIZZATOARIA']
df3['CORPISCALDANTIELETTRICIAUTONOMI']=riscaldamento['CORPISCALDANTIELETTRICIAUTONOMI']
df3['TELERISCALDAMENTO']=riscaldamento['TELERISCALDAMENTO']
df3['CONDIZIONAMENTOVENTILAZIONE']=riscaldamento['CONDIZIONAMENTOVENTILAZIONE']
df3['RISCALDAMENTOALTRANATURA']=riscaldamento['RISCALDAMENTOALTRANATURA']

# %% [markdown]
# I dataset presentano alcune disomogeneità, corrette con una serie di replace, che verranno utilizzate anche per l'ontologia:
#
# <i>In sostanza, abbiamo identificato la presenza o l'assenza di una determinata infrastruttura come True e False, in modo da trattarla come valore boolean.</i>

# %%
#Ambienti
df1=df1.replace({'-':'False'}, regex=True)
df1=df1.replace({'Non Comunicato':'False'}, regex=True)
df1=df1.replace({'Non Esiste':'False'}, regex=True)
df1=df1.replace({'Esiste':'True'}, regex=True)
df1=df1.replace({'SI':'True'}, regex=True)
df1=df1.replace({'NO':'False'}, regex=True)

#Barriere
df2=df2.replace({'SI':'True'}, regex=True)
df2=df2.replace({'NO':'False'}, regex=True)
df2=df2.replace({'-':'False'}, regex=True)

#Riscaldamento
df3=df3.replace({'SI':'True'}, regex=True)
df3=df3.replace({'NO':'False'}, regex=True)
df3=df3.replace({'-':'False'}, regex=True)

# %% [markdown]
# Alcuni campi presentano delle stringhe che descrivono il tipo di attrezzatura (diversa dagli altri campi), che abbiamo generalizzato allo stesso modo come True e False:

# %%
df2['ALTRIACCORGIMENTIDISABILI'] = df2['ALTRIACCORGIMENTIDISABILI'].replace({' ':''}, regex=True)
df3['RISCALDAMENTOALTRANATURA'] = df3['RISCALDAMENTOALTRANATURA'].replace({' ':''}, regex=True)
df2['ALTRIACCORGIMENTIDISABILI'] = df2['ALTRIACCORGIMENTIDISABILI'].replace({'[^a-zA-Z0-9]':''}, regex=True)
df3['RISCALDAMENTOALTRANATURA'] = df3['RISCALDAMENTOALTRANATURA'].replace({'[^a-zA-Z0-9]':''}, regex=True)
df2['ALTRIACCORGIMENTIDISABILI'] = df2['ALTRIACCORGIMENTIDISABILI'].replace({'\w+':'True'}, regex=True)
df3['RISCALDAMENTOALTRANATURA'] = df3['RISCALDAMENTOALTRANATURA'].replace({'\w+':'True'}, regex=True)

# %% [markdown]
# Output intermedi:

# %%
df1.to_csv('Output_ambiente.csv', index=False)
df2.to_csv('Output_barriere.csv', index=False)
df3.to_csv('Output_riscaldamento.csv', index=False)

# %% [markdown]
# Dopo aver pulito i 3 dataset, ne effettuiamo un merge per codice scuola e codice edificio, per poi ordinarle per codice scuola:

# %%
s1 = pd.merge(df1, df2, how='inner', on=['CODICESCUOLA','CODICEEDIFICIO'])
s2 = pd.merge(s1, df3, how='inner', on=['CODICESCUOLA','CODICEEDIFICIO'])
s2=s2.sort_values(by=['CODICESCUOLA'])

#Elimina tutte le scuole che non sono di Palermo
s2 = s2.loc[s2['CODICESCUOLA'].str.contains(r'^'+sigla+r'\w+')]

# %% [markdown]
# I dataset identificano la presenza o l'assenza di una determinata infrastruttura come True o False, quindi 1 o 0.
# Il rank viene calcolato effettuando una media aritmetica: <br>
# <b>Somma di ogni 'SI' presente / numero dei servizi totali </b> <br>
# <i>Il \* 10 serve per ottenere un numero compreso tra 1 e 10.</i>
#
# Infine, effettuiamo un round fino alla seconda cifra decimale e salviamo il file.

# %%
'''Prende tutti i campi necessari tranne quello del codice scuola e codice edificio, che non vengono 
utilizzati per il calcolo del rank
'''
num_elementi = len(s2.columns)
num_elementi -=2

s2['RANK'] = (s2.iloc[:,2:] == 'True').sum(axis=1)/num_elementi*10

s2['RANK'] = s2['RANK'].apply(lambda x: round(x, 2))


s2.to_csv('Output_rank.csv', index=False)

# %%
s2
# Out:
#       CODICESCUOLA  CODICEEDIFICIO SPAZIDIDATTICI AULAMAGNA  MENSA  \
# 34032   PAAA003039       820534065           True     False  False
# 34033   PAAA003039       820535039           True     False  False
# 34034   PAAA00305B       820534432           True     False  False
# 34035   PAAA012034       820534189           True     False  False
# 34036   PAAA012056       820534190           True     False  False
# 34037   PAAA01303X       820534724           True     False  False
# 34038   PAAA01303X       820534723          False     False  False
# 34039   PAAA013041       820533328           True     False  False
# 34040   PAAA017037       820534531           True     False  False
# 34041   PAAA017048       820533387           True     False  False
# 34042   PAAA01903V       820534809           True     False  False
# 34043   PAAA01903V       820533616           True     False  False
# 34044   PAAA01903V       820533614           True     False  False
# 34045   PAAA019084       820534396           True     False  False
# 34046   PAAA020066       820534656           True     False  False
# 34047   PAAA020077       820534658           True     False  False
# 34048   PAAA02902C       820534636           True     False  False
# 34049   PAAA02903D       820534559           True     False  False
# 34050   PAAA03103D       820534245           True     False  False
# 34051   PAAA03104E       820534217           True     False  False
# 34052   PAAA03105G       820534374           True     False  False
# 34053   PAAA03207D       820533312           True     False  False
# 34054   PAAA03211P       820533290           True     False  False
# 34055   PAAA033013       820534598           True      True  False
# 34056   PAAA033024       820534565           True     False  False
# 34057   PAAA03401V       820533279           True     False  False
# 34058   PAAA03402X       820534809           True     False  False
# 34059   PAAA034031       820534116           True     False  False
# 34060   PAAA034042       820534810           True     False  False
# 34061   PAAA03708N       820534400           True     False  False
# ...            ...             ...            ...       ...    ...
# 35242   PATD050008       820065015           True      True  False
# 35241   PATD050008       820065017           True      True  False
# 35240   PATD050008       820065016          False     False  False
# 35243   PATD05050N       820065015           True      True  False
# 35244   PATD09000P       820542676           True      True  False
# 35245   PATD09000P       820542985           True     False  False
# 35246   PATD090504       820542676           True      True  False
# 35247   PATD120009       820532951           True      True  False
# 35248   PATD12050P       820532951           True      True  False
# 35249   PATF01301L       820283821           True      True  False
# 35250   PATF01301L       820283829           True     False  False
# 35251   PATF01301L       820283828          False     False  False
# 35252   PATF013501       820283821           True      True  False
# 35253   PATF016014       820533444           True     False  False
# 35254   PATF01801Q       820554298           True      True  False
# 35255   PATF024013       820534746           True      True  False
# 35256   PATF02701E       820534742           True      True  False
# 35257   PATF02701E       820534743           True     False  False
# 35258   PATF02801A       820534415           True      True  False
# 35259   PATF030009       820535037           True     False  False
# 35260   PATF030009       820535031           True      True  False
# 35261   PATF03050P       820535031           True      True  False
# 35262   PATF03401N       820544807           True     False  False
# 35263   PATH03601R       820534804           True      True  False
# 35264   PATL011015       820784793           True     False  False
# 35265   PATL02601V       820532686           True      True  False
# 35266   PATL026518       820532686           True      True  False
# 35267   PATL033012       820534623           True     False  False
# 35268   PATN01000Q       820534767           True      True  False
# 35269   PATN010505       820534767           True      True  False
#
#       PALESTRAPISCINA SPAZIAMMINISTRATIVI SUPERAMENTOBARRIEREARCH  \
# 34032           False               False                    True
# 34033            True               False                    True
# 34034           False                True                    True
# 34035           False               False                   False
# 34036           False               False                    True
# 34037           False               False                    True
# 34038            True               False                    True
# 34039           False                True                    True
# 34040           False               False                    True
# 34041            True                True                    True
# 34042           False               False                   False
# 34043           False               False                    True
# 34044           False               False                   False
# 34045           False               False                    True
# 34046           False               False                   False
# 34047            True                True                   False
# 34048           False               False                    True
# 34049            True                True                    True
# 34050           False               False                    True
# 34051           False                True                    True
# 34052           False               False                    True
# 34053           False               False                    True
# 34054            True               False                    True
# 34055            True                True                    True
# 34056           False               False                   False
# 34057           False               False                    True
# 34058           False               False                   False
# 34059           False                True                    True
# 34060           False               False                   False
# 34061            True                True                    True
# ...               ...                 ...                     ...
# 35242           False                True                    True
# 35241           False                True                    True
# 35240            True               False                    True
# 35243           False                True                    True
# 35244            True                True                    True
# 35245           False               False                    True
# 35246            True                True                    True
# 35247            True                True                    True
# 35248            True                True                    True
# 35249           False               False                   False
# 35250           False               False                   False
# 35251            True               False                   False
# 35252           False               False                   False
# 35253            True               False                    True
# 35254            True                True                    True
# 35255            True                True                    True
# 35256           False                True                    True
# 35257            True                True                    True
# 35258           False                True                    True
# 35259           False               False                    True
# 35260            True                True                    True
# 35261            True                True                    True
# 35262           False                True                    True
# 35263            True                True                    True
# 35264           False                True                    True
# 35265            True                True                    True
# 35266            True                True                    True
# 35267            True                True                    True
# 35268            True                True                    True
# 35269            True                True                    True
#
#       ACCESSORAMPE SCALENORMA  ... CENTRALIZZATOOLIOCOMBUSTIBILI  \
# 34032         True      False  ...                         False
# 34033         True      False  ...                         False
# 34034         True      False  ...                         False
# 34035        False      False  ...                         False
# 34036         True      False  ...                         False
# 34037         True      False  ...                         False
# 34038         True      False  ...                         False
# 34039         True       True  ...                         False
# 34040         True       True  ...                         False
# 34041        False       True  ...                         False
# 34042        False      False  ...                         False
# 34043        False      False  ...                         False
# 34044        False      False  ...                         False
# 34045         True      False  ...                         False
# 34046        False      False  ...                         False
# 34047        False      False  ...                         False
# 34048         True      False  ...                         False
# 34049         True       True  ...                         False
# 34050         True      False  ...                         False
# 34051         True      False  ...                         False
# 34052         True      False  ...                         False
# 34053         True      False  ...                         False
# 34054         True       True  ...                         False
# 34055         True      False  ...                         False
# 34056        False      False  ...                         False
# 34057         True      False  ...                         False
# 34058        False      False  ...                         False
# 34059         True      False  ...                         False
# 34060        False      False  ...                         False
# 34061         True       True  ...                         False
# ...            ...        ...  ...                           ...
# 35242         True       True  ...                         False
# 35241         True       True  ...                         False
# 35240         True       True  ...                         False
# 35243         True       True  ...                         False
# 35244         True       True  ...                         False
# 35245         True       True  ...                         False
# 35246         True       True  ...                         False
# 35247         True       True  ...                         False
# 35248         True       True  ...                         False
# 35249        False      False  ...                         False
# 35250        False      False  ...                         False
# 35251        False      False  ...                         False
# 35252        False      False  ...                         False
# 35253         True       True  ...                         False
# 35254         True       True  ...                         False
# 35255         True      False  ...                         False
# 35256         True       True  ...                         False
# 35257         True       True  ...                         False
# 35258         True       True  ...                         False
# 35259         True       True  ...                         False
# 35260         True       True  ...                         False
# 35261         True       True  ...                         False
# 35262         True       True  ...                         False
# 35263        False       True  ...                         False
# 35264        False       True  ...                         False
# 35265         True       True  ...                         False
# 35266         True       True  ...                         False
# 35267         True       True  ...                         False
# 35268         True       True  ...                         False
# 35269         True       True  ...                         False
#
#       CENTRALIZZATOGASOLIO CENTRALIZZATOMETANO CENTRALIZZATOGPL  \
# 34032                False               False            False
# 34033                False                True            False
# 34034                False               False            False
# 34035                 True               False            False
# 34036                False                True            False
# 34037                False                True            False
# 34038                False                True            False
# 34039                False                True            False
# 34040                False                True            False
# 34041                False               False            False
# 34042                False               False            False
# 34043                False               False            False
# 34044                False               False            False
# 34045                False                True            False
# 34046                 True               False            False
# 34047                 True               False            False
# 34048                False               False            False
# 34049                False                True            False
# 34050                False                True            False
# 34051                False                True            False
# 34052                 True               False            False
# 34053                 True               False            False
# 34054                 True               False            False
# 34055                False                True            False
# 34056                False               False            False
# 34057                False                True            False
# 34058                False               False            False
# 34059                False                True            False
# 34060                False               False            False
# 34061                False                True            False
# ...                    ...                 ...              ...
# 35242                 True               False            False
# 35241                 True               False            False
# 35240                 True               False            False
# 35243                 True               False            False
# 35244                 True               False            False
# 35245                 True               False            False
# 35246                 True               False            False
# 35247                 True               False            False
# 35248                 True               False            False
# 35249                False               False            False
# 35250                False               False            False
# 35251                False               False            False
# 35252                False               False            False
# 35253                 True               False            False
# 35254                 True               False            False
# 35255                 True               False            False
# 35256                False                True            False
# 35257                False                True            False
# 35258                 True               False            False
# 35259                False                True            False
# 35260                False                True            False
# 35261                False                True            False
# 35262                 True               False            False
# 35263                False               False            False
# 35264                 True               False            False
# 35265                 True               False            False
# 35266                 True               False            False
# 35267                 True               False            False
# 35268                 True               False            False
# 35269                 True               False            False
#
#       CENTRALIZZATOARIA CORPISCALDANTIELETTRICIAUTONOMI TELERISCALDAMENTO  \
# 34032             False                            True             False
# 34033             False                           False             False
# 34034             False                           False             False
# 34035             False                           False             False
# 34036             False                           False             False
# 34037             False                           False             False
# 34038             False                           False             False
# 34039             False                           False             False
# 34040             False                           False             False
# 34041             False                           False             False
# 34042             False                           False             False
# 34043             False                           False             False
# 34044             False                           False             False
# 34045             False                           False             False
# 34046             False                           False             False
# 34047             False                           False             False
# 34048             False                            True             False
# 34049             False                           False             False
# 34050             False                           False             False
# 34051             False                           False             False
# 34052             False                           False             False
# 34053             False                           False             False
# 34054             False                           False             False
# 34055             False                           False             False
# 34056             False                           False             False
# 34057             False                           False             False
# 34058             False                           False             False
# 34059             False                           False             False
# 34060             False                           False             False
# 34061             False                           False             False
# ...                 ...                             ...               ...
# 35242             False                           False             False
# 35241             False                           False             False
# 35240             False                           False             False
# 35243             False                           False             False
# 35244             False                           False             False
# 35245             False                           False             False
# 35246             False                           False             False
# 35247             False                           False             False
# 35248             False                           False             False
# 35249             False                           False             False
# 35250             False                           False             False
# 35251             False                           False             False
# 35252             False                           False             False
# 35253             False                           False             False
# 35254             False                           False             False
# 35255             False                           False             False
# 35256             False                           False             False
# 35257             False                           False             False
# 35258             False                           False             False
# 35259             False                           False             False
# 35260             False                           False             False
# 35261             False                           False             False
# 35262             False                           False             False
# 35263             False                           False             False
# 35264             False                           False             False
# 35265             False                           False             False
# 35266             False                           False             False
# 35267             False                           False             False
# 35268             False                           False             False
# 35269             False                           False             False
#
#       CONDIZIONAMENTOVENTILAZIONE RISCALDAMENTOALTRANATURA RANK
# 34032                       False                     True  4.4
# 34033                       False                     True  4.8
# 34034                       False                     True  3.6
# 34035                       False                     True  2.0
# 34036                       False                     True  4.4
# 34037                       False                     True  4.4
# 34038                       False                     True  4.4
# 34039                       False                     True  5.6
# 34040                       False                     True  5.2
# 34041                       False                     True  3.6
# 34042                       False                     True  1.2
# 34043                       False                     True  2.0
# 34044                       False                     True  1.2
# 34045                       False                     True  4.4
# 34046                       False                     True  2.0
# 34047                       False                     True  2.8
# 34048                       False                     True  4.4
# 34049                       False                     True  5.6
# 34050                       False                     True  4.4
# 34051                       False                     True  4.8
# 34052                       False                     True  4.4
# 34053                       False                     True  4.4
# 34054                       False                     True  5.6
# 34055                       False                     True  5.6
# 34056                       False                     True  1.2
# 34057                       False                     True  3.6
# 34058                       False                     True  1.2
# 34059                       False                     True  4.4
# 34060                       False                     True  1.2
# 34061                       False                     True  6.0
# ...                           ...                      ...  ...
# 35242                       False                     True  6.0
# 35241                       False                     True  6.0
# 35240                       False                     True  5.2
# 35243                       False                     True  6.0
# 35244                       False                     True  6.0
# 35245                       False                     True  5.2
# 35246                       False                     True  6.0
# 35247                       False                     True  6.4
# 35248                       False                     True  6.4
# 35249                       False                     True  1.6
# 35250                       False                     True  1.2
# 35251                       False                     True  1.6
# 35252                       False                     True  1.6
# 35253                       False                     True  4.0
# 35254                       False                     True  5.2
# 35255                       False                     True  6.0
# 35256                       False                     True  6.0
# 35257                       False                     True  5.2
# 35258                       False                     True  5.6
# 35259                       False                     True  4.8
# 35260                       False                     True  6.4
# 35261                       False                     True  6.4
# 35262                       False                     True  5.6
# 35263                       False                     True  4.0
# 35264                       False                     True  4.4
# 35265                       False                     True  6.4
# 35266                       False                     True  6.4
# 35267                       False                     True  6.0
# 35268                       False                     True  6.0
# 35269                       False                     True  6.0
#
# [1238 rows x 28 columns]

# %% [markdown]
# Il file <b>Output_rank</b> contiene:
# - Codice della scuola,
# - Codice edificio,
# - Infrastrutture presenti, come ad esempio aula magna, mensa, spazi amministrativi ecc.
# - Rank (valutazione)
